# %% [markdown]
# # Run n8n locally
#
# ```bash
# docker volume create n8n_data
# docker run -it --rm --name n8n -p 5678:5678 -v n8n_data:/home/node/.n8n docker.n8n.io/n8nio/n8n
# ```

# %% [markdown]
# Access the editor at `http://localhost:5678`

# %% [markdown]
# # Try any of these and share screenshots:
# * [Your First AI Agent](https://drive.google.com/file/d/1Rbq3xqiqBqL4IL3EL0O0r74Vpxsz_UXN/view?usp=sharing)
# * [AI Newsletter Automation v0.1](https://drive.google.com/file/d/1SkEWZctqRWIkS78VA3VCLLZhhjEYygai/view?usp=sharing)
# * [AI Newsletter Automation v1.0](https://drive.google.com/file/d/1Gv7TCKkDOkLe1rutI2kYTO2rQi0S5q3S/view?usp=sharing)

# %% [markdown]
# # n8n Workflows (Submission)

# %% [markdown]
# ## Your First AI Agent

# %% [markdown]
# ![Screenshot 2025-10-01 at 10.02.37 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-10-01 at 10.03.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## AI Newsletter Automation v0.1

# %% [markdown]
# ![Screenshot 2025-10-01 at 10.05.05 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-10-01 at 10.09.06 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## AI Newsletter Automation v1.0

# %% [markdown]
# ![Screenshot 2025-10-01 at 10.15.46 PM.png](data:image/png;base64,...)
